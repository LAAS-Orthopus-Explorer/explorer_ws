# %%
# %run mpc_orthopus.py
# Out:
# ROS msg not found
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /src/src/explorer_ws/laas_explorer_stack/laas_controller/laas_controller/mpc_orthopus.py in ?()
#     509     rclpy.shutdown()'''
#     510
#     511 if __name__ == '__main__':
#     512     #main()
# --> 513     campero = ManagerMpcAcados(CamperoDynamicCfg())
#     514     print(campero)
#     515     print(campero.name)
#     516     x = np.zeros(campero.nx)
#
# /usr/local/lib/python3.10/dist-packages/o2r_pi2_controllers/managers/manager_mpc_acados.py in ?(self, cfg, **kwargs)
#      67         for attr in cost_required_attrs:
#      68             if not hasattr(cfg.cost, attr):
#      69                 raise AttributeError(f"Missing required attribute '{attr}' in {cls.__name__}")
#      70
# ---> 71         orig_init(self, cfg, **kwargs)
#
# ...

# %%
# %run mpc_orthopus.py
# Out:
# ROS msg not found
# universe                 :  0.00  0.00  0.00
# joint_1                  :  0.00  0.00  0.06
# joint_2                  :  0.00  0.03  0.11
# joint_3                  :  0.00  0.03  0.53
# joint_4                  :  0.00  0.02  0.72
# joint_5                  :  0.00 -0.01  0.82
# joint_6                  :  0.00  0.02  0.97
# left_external_rod_joint  :  0.01  0.07  1.08
# left_fingertip_joint     :  0.01  0.10  1.12
# left_finger_joint        :  0.02  0.06  1.07
# right_external_rod_joint :  0.01 -0.04  1.08
# right_fingertip_joint    :  0.01 -0.06  1.12
# right_finger_joint       :  0.02 -0.02  1.07
# robot model: MPC_Orthupus_Kinematics
# x [ 0.1  -0.2   0.15 -0.1   0.05  0.    0.2  -0.1   0.1   0.   -0.05  0.05]
# Trajectory_arm: [0.3 0.3 0.3]
# error: [-0.0760829, -0.259661, 0.638821]
# costo: 0.481305
# Posición del efector con x=0: [0.223917, 0.0403393, 0.938821]
# Cost:  1.15827e+07
# Trajectory_arm: [refs_2, refs_3, refs_4]
# ...
